# %%
import pySPM
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import os
from IPython import display

# %%
filenameB = r'data/example_data/afm/MBE1-230404A-MS.0_00000.spm'
ScanB = pySPM.Bruker(filenameB)
ScanB.list_channels()
# Out:
# Channels
# ...
# 	S [ZSensor] "Height Sensor"
# 	S [PeakForceError] "Peak Force Error"
# 	S [ZSensor] "Height Sensor"
# 	S [PeakForceError] "Peak Force Error"

# %%
ScanB.get_channel('Height Sensor').show()

# %%
im = plt.imshow(ScanB.get_channel().correct_plane().pixels, 'afmhot')
plt.colorbar(im)
